# %% [markdown]
# # Used only for internal use. Do not consider for the project.

# %%
# Import packages
import gymnasium as gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import torch
import time
from collections import deque

from IPython.display import clear_output

# %%
env = gym.make("InvertedDoublePendulum-v4", render_mode='rgb_array')
env.reset()
plt.imshow(env.render())
plt.title('Environment Image')
plt.show()

# %%
print(env.step((0, )))
plt.imshow(env.render());
# Out:
# (array([ 0.02084948,  0.03338009,  0.03503124,  0.99944273,  0.99938622,
#        -0.05540547,  0.29672585,  0.12667923,  0.        ,  0.        ,
#         0.        ]), 9.356980147972394, False, False, {})

# %%
state, _, _, _, _ = env.step((0, ))

# %%
print(state)
# Out:
# [ 0.01782844  0.04885789  0.04253951  0.99880574  0.99909479 -0.0661429
#   0.3259128   0.17267165  0.          0.          0.        ]
